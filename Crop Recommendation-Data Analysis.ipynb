# %%
#Importing pandas library
import pandas as pd

#Creating the dataframe of the Crop Recommendation Data Set
df = pd.read_csv('Crop_recommendation_cleaned.csv')

#Showing the upper 5 data in the dataframe
df.head()
# Out:
#     N   P     K  temperature   humidity        ph    rainfall label
# 0  90  42  43.0    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41.0    21.770462  80.319644  7.038096  213.841241  rice
# 2  60  55  44.0    23.004459  82.320763  7.840207  213.841241  rice
# 3  74  35  40.0    26.491096  80.158363  6.980401  213.841241  rice
# 4  78  42  42.0    20.130175  81.604873  7.628473  213.841241  rice

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   float64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   str
# dtypes: float64(5), int64(2), str(1)
# memory usage: 153.0 KB

# %%
print("\nBasic stats:\n", df.describe())
# Out:
# Basic stats:
#                   N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    52.743182    38.376364    25.588740    71.493347
# std      36.917334    31.427156    23.460322     4.738804    22.234536
# min       0.000000     5.000000     5.000000    14.080956    15.731726
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   128.000000    92.500000    37.250073    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.464205   101.986465
# std       0.730288    51.165743
# min       4.543768    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       8.351567   213.841241

# %%
# Mean / Average
df.mean(numeric_only=True)

# Standard deviation
df.std(numeric_only=True)

# Sum
df.sum(numeric_only=True)

# Correlation
df.corr(numeric_only=True)

# Complete statistical summary
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    52.743182    38.376364    25.588740    71.493347
# std      36.917334    31.427156    23.460322     4.738804    22.234536
# min       0.000000     5.000000     5.000000    14.080956    15.731726
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   128.000000    92.500000    37.250073    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.464205   101.986465
# std       0.730288    51.165743
# min       4.543768    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       8.351567   213.841241

# %%
#Unique values in each attribute in the dataset
for j in df.columns:
    print(j)
    print(df[j].unique())
# Out:
# N
# [ 90  85  60  74  78  69  94  89  68  91  93  77  88  76  67  83  98  66
#   97  84  73  92  95  99  63  62  64  82  79  65  75  71  72  70  86  61
#   81  80 100  87  96  40  23  39  22  36  32  58  59  42  28  43  27  50
#   25  31  26  54  57  49  46  38  35  52  44  24  29  20  56  37  51  41
#   34  30  33  47  53  45  48  13   2  17  12   6  10  19  11  18  21  16
#    9   1   7   8   0   3   4   5  14  15  55 105 108 118 101 106 109 117
#  114 110 112 111 102 116 119 107 104 103 120 113 115 133 136 126 121 129
#  122 140 131 135 123 125 139 132 127 130 134]
# P
# [ 42  58  55  35  37  53  54  46  56  50  48  38  45  40  59  41  47  49
#   51  57  39  43  44  60  52  36  72  67  73  70  62  74  66  63  71  78
#   80  68  65  77  76  79  61  64  69  75  24  18  26  27  25  21  30  11
#    5  10   7  20  22  15  23   8  16  29  17   6  19  13   9  14  28  94
#   95  92  89  88  87  85  86  83  91  81  84  90  82  93  33  31  34  32
#  128 123 125 122 121 126 120 127 124  12]
# K
# [43.  41.  44.  40.  42.  38.  36.  37.  39.  35.  45.  16.  17.  21.
#  20.  19.  25.  22.  15.  18.  23.  24.  77.  84.  85.  81.  75.  79.
#  76.  83.  78.  80.  82.  46.  50.  53.  54.  49.  55.  52.  47.  48.
#  51.  27.  31.  32.  34.  33.  30.  28.  29.  26.  92.5 12.  13.   6.
#   9.  10.  14.   8.   7.   5.  11. ]
# temperature
# [20.87974371 21.77046169 23.00445915 ... 24.13179691 26.2724184
#  23.60301571]
# humidity
# [82.00274423 80.31964408 82.3207629  ... 67.22512329 52.12739421
#  60.39647474]
# ph
# [6.50298529 7.03809636 7.84020714 ... 6.36260785 6.75879255 6.77983261]
# rainfall
# [202.9355362 213.8412405 185.2773389 ... 173.3228386 127.1752928
#  140.9370415]
# label
# <ArrowStringArray>
# [       'rice',       'maize',    'chickpea', 'kidneybeans',  'pigeonpeas',
#    'mothbeans',    'mungbean',   'blackgram',      'lentil', 'pomegranate',
#       'banana',       'mango',      'grapes',  'watermelon',   'muskmelon',
#        'apple',      'orange',      'papaya',     'coconut',      'cotton',
#         'jute',      'coffee']
# Length: 22, dtype: str

# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_matrix
# Out:
#                     N         P         K  temperature  humidity        ph  \
# N            1.000000 -0.227834  0.019000     0.023850  0.190746  0.106321
# P           -0.227834  1.000000  0.561850    -0.132569 -0.138850 -0.140243
# K            0.019000  0.561850  1.000000    -0.164312  0.120765 -0.107937
# temperature  0.023850 -0.132569 -0.164312     1.000000  0.212362 -0.020906
# humidity     0.190746 -0.138850  0.120765     0.212362  1.000000  0.000323
# ph           0.106321 -0.140243 -0.107937    -0.020906  0.000323  1.000000
# rainfall     0.044041 -0.063986 -0.026358    -0.041047  0.085163 -0.119116
#
#              rainfall
# N            0.044041
# P           -0.063986
# K           -0.026358
# temperature -0.041047
# humidity     0.085163
# ph          -0.119116
# rainfall     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix of Agricultural Variables")
plt.show()

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df['label'].value_counts().sort_index()
# Out:
# label
# apple          100
# banana         100
# blackgram      100
# chickpea       100
# coconut        100
# coffee         100
# cotton         100
# grapes         100
# jute           100
# kidneybeans    100
# lentil         100
# maize          100
# mango          100
# mothbeans      100
# mungbean       100
# muskmelon      100
# orange         100
# papaya         100
# pigeonpeas     100
# pomegranate    100
# rice           100
# watermelon     100
# Name: count, dtype: int64

# %%
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.boxplot(data=df.select_dtypes(include='number'))
plt.xticks(rotation=45)
plt.title("Boxplots of Numerical Variables")
plt.show()

# %%
df.groupby('label')[['N', 'P', 'K', 'temperature', 
                     'humidity', 'ph', 'rainfall']].mean()
# Out:
#                   N       P      K  temperature   humidity        ph  \
# label
# apple         20.80  126.66  92.50    22.630942  92.333383  5.929663
# banana       100.23   82.01  50.05    27.376798  80.358123  5.983893
# blackgram     40.02   67.47  19.24    29.973340  65.118426  7.133952
# chickpea      40.09   67.79  79.92    18.872847  17.114928  7.295763
# coconut       21.98   16.93  30.59    27.409892  94.844272  5.976562
# coffee       101.20   28.74  29.94    25.540477  58.869846  6.790308
# cotton       117.77   46.24  19.56    23.988958  79.843474  6.912675
# grapes        23.18  126.46  92.50    24.084137  81.875228  6.025937
# jute          78.40   46.86  39.99    24.958376  79.639864  6.732778
# kidneybeans   20.75   67.54  20.05    20.115085  21.605357  5.749411
# lentil        18.77   68.36  19.41    24.509052  64.804785  6.927932
# maize         77.76   48.44  19.79    22.389204  65.092249  6.245190
# mango         20.07   27.18  29.92    31.208770  50.156573  5.766916
# mothbeans     21.44   48.01  20.23    28.194920  53.160418  6.755765
# mungbean      20.99   47.28  19.87    28.525775  85.499975  6.723957
# muskmelon    100.32   17.72  50.08    28.663066  92.342802  6.358805
# orange        19.58   16.55  10.01    23.158815  92.170209  7.016957
# papaya        49.88   59.05  50.04    32.491130  92.403388  6.741442
# pigeonpeas    20.73   67.73  20.29    27.741762  48.061633  5.794175
# pomegranate   18.87   18.75  40.21    21.837842  90.125504  6.429172
# rice          79.89   47.58  39.87    23.689332  82.272822  6.425471
# watermelon    99.42   17.00  50.22    25.591767  85.160375  6.495778
#
#                rainfall
# label
# apple        112.654779
# banana       104.626980
# blackgram     67.884151
# chickpea      80.058977
# coconut      174.697366
# coffee       158.066295
# cotton        80.398043
# grapes        69.611829
# jute         174.792798
# kidneybeans  105.919778
# lentil        45.680454
# maize         84.766988
# mango         94.704515
# mothbeans     51.198487
# mungbean      48.403601
# muskmelon     24.689952
# orange       110.474969
# papaya       139.205102
# pigeonpeas   149.457564
# pomegranate  107.528442
# rice         208.094939
# watermelon    50.786219

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(data=df, x='label', y='N')
plt.xticks(rotation=90)
plt.title("Nitrogen Distribution by Crop")
plt.show()

# %%
df.select_dtypes(include='number').skew()
# Out:
# N              0.509721
# P              0.836609
# K              1.116640
# temperature    0.070778
# humidity      -1.087575
# ph             0.146471
# rainfall       0.663507
# dtype: float64

# %%
numeric = df.select_dtypes(include='number')

cv = (numeric.std() / numeric.mean()) * 100
print(cv)
# Out:
# N              73.028696
# P              59.585250
# K              61.132217
# temperature    18.519099
# humidity       31.100147
# ph             11.297422
# rainfall       50.169150
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
skewness.plot(kind='bar')

plt.title('Skewness of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Skewness')
plt.axhline(0, linewidth=1)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
cv.plot(kind='bar')

plt.title('Coefficient of Variation of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Coefficient of Variation (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.nunique()
# Out:
# N               137
# P               100
# K                63
# temperature    2116
# humidity       2171
# ph             2145
# rainfall       2101
# label            22
# dtype: int64

# %%
import matplotlib.pyplot as plt

label_counts = df['label'].value_counts()

plt.figure(figsize=(12, 6))
label_counts.plot(kind='bar')

plt.title('Distribution of Crop Categories')
plt.xlabel('Crop')
plt.ylabel('Number of Observations')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
